# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# ## Authors
# - Olivia Cong: Project administration, Data curation, Analysis, Writing - original draft
# - Savannah Hughes:  Project administration, Data curation, Writing - review & editing
# - Elizabeth Sushkova: Project administration, Background research, Analysis, Writing - review & editing
# - Jessie Zheng: Analysis, Background research, Analysis, Visualization, Writing - original draft

# %% [markdown]
# ## Research Question

# %% [markdown]
# How do daily weather fluctuations, as measured by average temperature, affect university students’ self reported depression and anxiety levels, as measured by scores on anxiety or depressive feelings questionnaire? Do daily weather fluctuations have an effect on the duration of sleep university students get per night? Is there an association between nightly sleep duration and self reported feelings of depression and anxiety in students?
#
# **Update notes:** We opted to add the analysis of if weather fluctuations affect total sleep duration per night rather than link the students' depressive feelings to academic performance.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Weather is thought to have significant impacts on human well being. Psychologically this phenomenon can be explained by Maslow's Hierarchy of needs where reliable good weather conditions can satisfy an individual's basic physiological and safety needs (1). “The evolutionary theory posits that humans have an inherent positive preference for non-threatening environmental factors in nature, which helps to promote survival and enhance well-being” (1). Light and temperature show to play a role in people's physiological and psychological state, sufficient sunlight and warm temperature are often correlated with positive emotions and mental state (1). The association between weather and well-being is due to a combination of factors, including light, temperature, air quality and several other weather conditions. The positive effect of sunlight could be due to more accessibility to the outdoors which bolsters life satisfaction (1). Sunlight has direct impacts on the production of melatonin, a hormone responsible for the regulation of the circadian rhythm and neurotransmitters associated with happiness and well-being like serotonin, dopamine, and endorphins. (1).
#
# A study (2) on SAD (seasonal affective disorder) in students examined whether a college student’s risk of developing symptoms of seasonal affective disorder is higher when they moved from a home town with minimal seasonal weather fluctuations (like Hawaii) to a university located in an area of high seasonality (like Pennsylvania). The authors hypothesized that students raised in non-seasonal environments would show larger winter increases in depressive symptoms compared to students from highly seasonal hometowns. Using an adapted version of the Seasonal Patterns Assessment Questionnaire (SPAQ) administered to 3 different universities in the fall (as baseline) and again in the winter and comparing that data to publicly available climate data, they found that nearly 50% of students from non-seasonal hometowns reported an increased SPAQ score in the winter, compared to no change for those with non-seasonal hometowns. Students from non-seasonal hometowns appear to experience greater seasonal shifts in mood and there are other adaptive factors that affect seasonal mood changes.(2).
#
# A study on the effects of weather on sleep patten has shown a “small but statistically significant effects of seasonal and weather effects on sleep patterns” (3) finding that “the strongest seasonal effects for wake time and sleep duration, especially during the spring season: wake times are earlier, and sleep duration decreases (compared to the reference season winter)” (3). “Sleep duration also modestly decreases when day lengths get longer (between the winter and summer solstice). Bedtimes and wake times tend to be slightly later as outdoor temperature increases” (3). Several demographics were controlled for including age, sex, organization, supervisory role, latitude, and longitude of home location as well as psychological traits associated with sleep using the Positive and Negative Affect Schedule (PANAS X) for affect balance, Big Five Inventory (BFI) for personality, the Pittsburgh Sleep Quality Index (PSQI) for sleep quality, and Morning-Eveningness Questionnaire (MEQ)107 for chronotype (3). This study shows that there is a correlation between seasonality and sleep duration with longer day lengths associated with less nightly sleep duration. For every hour increase in daylight, sleep duration decreases by 3.6 minutes. However, “the addition of weather variables (temperature, wind, and humidity/cloud cover) in the full model did not explain significantly more variance” (3).
#
# The effect of sleep duration on general health outcomes was also looked at in a study that took self reported sleep data from the a sample of US adults and categorized them into 3 groups: short sleep (≤5 hours), recommended sleep (6–8 hours), and long sleep (≥9 hours) (7). Health outcomes were measured in a variety of ways including self-reported diagnosis of depression, number of poor mental health days, number of poor physical health days, and self-rated general health, measured on a 5-point Likert scale from excellent to poor (7). The study found that short sleep duration (≤5 hours) was associated with a 14.1 percentage point increase in depression incidence (95% CI: 13.8%–14.4%), while long sleep duration (≥9 hours) was linked to a 12.9 percentage point increase (7). Both short and long sleep groups also reported having more poor mental and physical health days as well as lower self-rated general health (7). This study shows that there is a correlation between sleep duration and general mood and well-being, with the best outcomes coming from people who sleep on average 6 to 8 hours per night.
#
# Another study (3) examined whether students’ happiness (subjective well-being) predicts academic performance, and whether gender differences exist during the disruption of the COVID-19 pandemic. They used The Oxford Happiness Questionnaire (OHQ) as a self reported measure of happiness and grade point average as a measure of academic success. Data analysis revealed that higher education students in the UAE have high levels of happiness and academic success with no gender difference, indicating that students’ happiness levels were positively correlated to their academic success. (3).
#
# While many prior studies rely on surveys and psychological assessments, recent research has increasingly used large-scale behavioral datasets to examine how weather influences mood in real-world settings. Another study (4) of prior work examines weather influences on emotional states at scale using large datasets, linking environmental conditions to expressed sentiment and mood beyond traditional survey methods. For example, one large analysis of 3.5 billion social media posts from Facebook and Twitter found that multiple weather variables like temperature, precipitation, humidity, and cloud cover, were strongly associated with the sentiment expressed in people’s posts. Adverse weather conditions correspond to more negative emotional expression in its data (4). Similarly, a global study of 1.2 billion social media posts across 157 countries observed that extremely high temperatures were associated with more negative moods. In other words, climate variables were found to be related to mood at the global level (5). Recent research using computational methods has improved the way that language and regional variations are taken into account when examining the relationship between weather and sentiment on social media. The research points to the complex relationship that weather has with mood and the importance of using context-sensitive analysis when examining data (6). These studies show that data science techniques are effective in examining the relationship that weather has with mood and that similar techniques could be used in our project.
#
# References
#
# 1. Overview on the Effect of Weather and Happiness. PubMed Central (PMC). https://pmc.ncbi.nlm.nih.gov/articles/PMC12272345/
# 2. Study on Weather and Happiness. PubMed Central (PMC). https://pmc.ncbi.nlm.nih.gov/articles/PMC8646863/
# 3. Study on the Effects of Weather and Sleep (PMC) https://pmc.ncbi.nlm.nih.gov/articles/PMC8080821/
# 4. Baylis, P. et al. (2018) Weather impacts expressed sentiment. PLOS ONE. https://pubmed.ncbi.nlm.nih.gov/29694424/
# 5. Wang, J. et al. (2025) Unequal impacts of rising temperatures on global human sentiment. One Earth. https://phys.org/news/2025-08-temperatures-linked-declining-moods-world.html
# 6. Linguistic and emotional effects of weather. Scientific Reports (Nature). https://www.nature.com/articles/s41598-024-82384-w
# 7. Study on Effects of Sleep and General Well-being (PMC) https://pmc.ncbi.nlm.nih.gov/articles/PMC12803467/#abstract1
#
# **Update notes** Background was updated to appropriately reflect the change in our research question. We focused on weather's effects on anxiety/depression and sleep.

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that as the average weekly temperature increases, self-reported levels of anxiety and depression will go down in university students (signifying lower levels of anxiety and depression). We also predict that as the average weekly temperature decreases, self-reported anxiety or depressive feelings questionnaire scores will increase (signifying higher levels of anxiety and depression). We predict that lower average weekly temperatures will also increase sleep duration and that there is an association between sleep duration and self-reported depression and anxiety ratings.
#
# We believe this hypothesis because of the current accepted theory that sunlight affects the circadian rhythm, which in turn has an effect on mood regulation and, by extension, levels of self-reported depression and anxiety (1) as well as the individual studies relating climate patterns and SAD rates in university students (2). We believe that there is a negative association between temperature and sleep patterns, with lower temperatures increasing average sleep duration because lower temperatures limit the appeal and availability of outside activities and are usually associated with “poor weather,” which increases the likelihood of students staying inside and therefore provides more opportunity for sleep. Lastly, we believe that there will be an association with sleep times and self-reported depression and anxiety ratings due to studies (2) findings that people who sleep more or less than 6-8 hours report higher levels of depression.
#
# **Update notes:** Hypothesis was also updated to reflect change in research question. We are no longer investigating academic performance and now making predictions regarding weather's effect on depression/anxiety and sleep.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: GLOBEM (Global Longitudinal Study of Behavioral and Emotional Monitoring)
#   - Link to the dataset: https://the-globem.github.io/datasets/overview
#
# Note: Direct access to dataset is restricted. Data must be requested and accessed locally due to privacy concerns.
#
# - Number of observations: The dataset contains longitudinal repeated measures across multiple waves. For example, the weekly depression survey (dep_weekly.csv) for a single wave contains ~2,200–2,400 observations (rows), where each row represents a participant-week entry. Across all waves, the total number of observations is substantially larger due to repeated measures.
# - Number of variables: The number of variables depends on the specific data file:
#   - bluetooth.csv — 894 variables
#   - call.csv — 786 variables
#   - dep_endterm.csv — 5 variables
#   - dep_weekly.csv — 9–10 variables(depends on site/version)
#   - ema.csv — 4–9 variables (depends on site/version)
#   - location.csv — 1110 variables
#   - platform.csv — 2 variables
#   - post.csv — 26–27 variables
#   - pre.csv — 23–32 variables (varies by site/version)
#   - rapids.csv — 5511 variables
#   - screen.csv — 1137 variables
#   - sleep.csv — 921 variables
#   - steps.csv — 597 variables
#   - wifi.csv — 84 variables
#
# The GLOBEM dataset consists of multiple sub-datasets. The number of variables varies across files.
#
# - Description of the variables most relevant to this project:
#   - Measuring depression and anxiety: dep_weekly.csv
#     - pid: unique identifier for each participant that can be used to merge this dataset with sleep data.
#     - date: Used to align with sleep and weather data and will be used for time series and temporal matching.
#     - phq4: Total score form the PHQ-4 (Patient Health Questionnaire-4) ranging from 0-12 with higher scores indicating greater psychological stress as it relates to depression and anxiety symptoms serving as mental health outcome variable.
#   - Sleep data: sleep.csv
#     - pid: participant ID, used to merge with mental health data
#     - date: date of sleep measurement, used to merge with mental health and weather data
#     - sumduration (type = "main"): total nightly sleep duration, measured in minutes, represents total sleep per night
# - Shortcomings this dataset has with respect to the project: There is potential for self-selection bias because participants volunteered for the study. Missing data is likely systematic due to longitudinal nature of study (ie people are more likely to stop participating in the survey if they have greater feelings of depression and anxiety). Protected demographic information means that we cannot test downstream bias or control for demographic confounders. Because this data is observational and self-reported for both mental health variables and sleep duration, causal conclusions cannot be drawn.
#
#
# - Dataset #2
#   - Dataset Name: Open-Mateo Historical Forecast API
#   - Link to the dataset:https://open-meteo.com/en/docs/historical-forecast-api
#   - Number of observations: The number of observations depends on the specific data file:
#     - open-meteo-47.63N122.32W59m-2019.csv - 2328 observations
#     - open-meteo-47.63N122.32W59m-2020.csv - 2232 observations
#     - open-meteo-47.63N122.32W59m-2021.csv - 2472 observations
#   - Number of variables: The number of variables depends on the specific data file:
#     - open-meteo-47.63N122.32W59m-2019.csv - 6 variables
#     - open-meteo-47.63N122.32W59m-2020.csv - 6 variables
#     - open-meteo-47.63N122.32W59m-2021.csv - 6 variables
#   - Description of the variables most relevant to this project:
#     - The Open-Mateo Historical Forecast API provides an hourly historical record of temperature in Seattle, Washington. This dataset consists of 3 sub-sets, each sub-sets contain hourly Seattle weather data from spring to summer in 2019-2021 measured in Fahrenheit. Weather data are from weather stations, satellites, radar, airplanes, soundings, and buoys. With high update frequencies of 1, 3, or 6 hours, the resulting time series is nearly as accurate as direct measurements and offers global coverage. The specific date of the dataset is also selected according to the sleep data and anxiety and depression data from GLOBEM dataset.
#   - Descriptions of any shortcomings this dataset has with repsect to the project
#     - A primary concern of this dataset is the presence of extreme climatic outliers due to significant climate change. Some extreme weather occurs and creates statistical skew. Moreover, since the dataset does not include variables such as precipitation or cloud cover, it does not provide a complete picture of overall weather conditions. For instance, on weather forecasts, the 'feels like' temperature often differs from the actual air temperature, which may affect how participants feel about the weather and affect their sleep or mental health. Additionally, because most historical weather APIs source their data from Sea-Tac Airport, the recorded temperatures may differ by several degrees from those observed in downtown Seattle or other neighborhoods. Participants from different districts may feel differently, affecting their performance on self-report questionnaires. In addition, the temperature data is measured in hours, which is too specific and not necessary for our project.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# GLOBEM Data is restricted and thus only used locally. Weather data is uploaded to the Github repo.

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

# import sys
# sys.path.append('./modules') # this tells python where to look for modules to import

# import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
# datafiles = [
   # { 'url': 'https://physionet.org/content/globem/1.1/', 'filename':'airline-safety.csv'},
   # { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
# ]

# get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:   0%|          | 0/3 [00:00<?, ?it/s]
# ...
# Successfully downloaded: airline-safety.csv
# ...
# Successfully downloaded: bad-drivers.csv
# ...
# Overall Download Progress: 100%|██████████| 3/3 [00:00<00:00,  3.47it/s]
# Successfully downloaded: weather-2019

# %% [markdown]
# ### Anxiety and Depression Dataset (GLOBEM - dep_weekly.csv)
#
# The anxiety and depression dataset contains self-reported questionnaire measures the asses psychological distress, which were collected from undergraduate students from the University of Washington between the years of 2018-2021 as part of a multi-year mobile and wearable sensing dataset (GLOBEM). Within the PHQ-4 (Patient Health Questionnaire-4), there are questions on depression and two on anxiety (exact questions can be viewed here: https://northwestpainguidance.org/wp-content/uploads/2016/05/PHQ-4.pdf).
#
# Each item is scored from 0 ("Not at all") to 3 ("Nearly every day"). The sum of the responses to all four questions produces a total score ranging from 0-12, with higher scores equating to greater psychological distress. Scores of 0-2 represent normal levels, 3-5 mild symptoms, 6-8 moderate symptoms, and 9-12 indicate severe symptoms.
#
# These measures rely on self-report and, therefore, may reflect reporting bias, different interpretations of the questions, and missing responses. The PHQ-4 is not meant to serve as a clinical diagnosis but rather as a screening tool; therefore, higher scores may indicate greater symptom severity but not a diagnosis. PHQ-4 is a variable missing from 2018 surveys, so we make the choice to exclude the year 2018 from further investigation to remain consistent.

# %%
# Import basic packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest, kstest, norm
import os
import glob

# %%
# Load in weekly anxiety/depression survey data.
df_2019_dep_weekly = pd.read_csv('data/00-raw/GLOBEMDataset/INS-W_2/SurveyData/dep_weekly.csv')
df_2020_dep_weekly = pd.read_csv('data/00-raw/GLOBEMDataset/INS-W_3/SurveyData/dep_weekly.csv')
df_2021_dep_weekly = pd.read_csv('data/00-raw/GLOBEMDataset/INS-W_4/SurveyData/dep_weekly.csv')

# %% [markdown]
# Each year is formatted the same. Let's take a look at 2019's data shape and the first few rows.

# %%
print(df_2019_dep_weekly.shape)
df_2019_dep_weekly.head()
# Out:
# (2256, 9)
#    Unnamed: 0        pid        date  phq4    dep  BDI2 dep_weekly_subscale  \
# 0           0  INS-W_300  2019-03-31   2.0  False   NaN               False
# 1           1  INS-W_300  2019-04-07   3.0   True   NaN               False
# 2           2  INS-W_300  2019-04-11   3.0   True   NaN               False
# 3           3  INS-W_300  2019-04-21   5.0   True   NaN                True
# 4           4  INS-W_300  2019-04-28   5.0   True   NaN                True
#
#   anx_weekly_subscale  dep_weeklysubscale_endterm_merged
# 0               False                              False
# 1               False                              False
# 2               False                              False
# 3               False                               True
# 4               False                               True

# %% [markdown]
# We only want PHQ-4. Drop all unneeded columns to the right and the duplicate index column.

# %%
# Create a list of columns we want to drop in our dataframe.
dep_weekly_drop_columns = ['Unnamed: 0', 'dep', 'BDI2', 'dep_weekly_subscale', 'anx_weekly_subscale', 'dep_weeklysubscale_endterm_merged']

# Drop all columns to the right of PHQ-4.
df_2019_dep_weekly_1 = df_2019_dep_weekly.drop(columns=dep_weekly_drop_columns)
df_2020_dep_weekly_1 = df_2019_dep_weekly.drop(columns=dep_weekly_drop_columns)
df_2021_dep_weekly_1 = df_2019_dep_weekly.drop(columns=dep_weekly_drop_columns)

# %% [markdown]
# Drop rows with NaN values to obtain final cleaned datasets.

# %%
# Drop rows with missing values.
df_2019_dep_weekly_cleaned = df_2019_dep_weekly_1.dropna(axis=0, how='any', inplace=False)
df_2020_dep_weekly_cleaned = df_2020_dep_weekly_1.dropna(axis=0, how='any', inplace=False)
df_2021_dep_weekly_cleaned = df_2021_dep_weekly_1.dropna(axis=0, how='any', inplace=False)

# %% [markdown]
# ### Sleep Dataset (GLOBEM - sleep.csv)
#
# The sleep dataset contains passively collected daily sleep metrics from sleep-related features from RAPIDS-Fitbit-Sleep collected from undergraduate students from the University of Washington between the years of 2018-2021 as part of multi-year mobile and wearable sensing dataset (GLOBEM). The primary variable that is relevant for this project is the nightly sleep duration for main sleep episodes. Main sleep episodes refer to the primary nighttime sleep period and exclude naps from total sleep duration. This is stored in the sumdurationasleepmain feature, which contains the total sleep duration for a certain sleep type during a time segment recorded in minutes. For undergraduate university-age students, the average recommended sleep duration is around 7-9 hours per night (420-590 minutes). Values consistently below 6 hours indicate potential for sleep deprivation, and values consistently over 9 or 10 hours may indicate hypersomnia.
#
# Major concerns with this dataset is the fact that sleep duration is inferred from the Fitbit device data instead of being clinically measured, which means that sleep duration estimates are more prone to error if the devices are not worn or are inactive. Missingness from data may not be random if participants forgot or disabled their devices. This tracking device also does not capture sleep duration quality. In addition, each year has portions of missing sleep data from participants during periods of time. This may affect results.

# %% [markdown]
# To stay consistent, we exclude 2018 and use 2019-2021. Load in sleep.csv for each year.

# %%
# Load in sleep data.
df_sleep_19 = pd.read_csv('data/00-raw/GLOBEMDataset/INS-W_2/FeatureData/sleep.csv')
df_sleep_20 = pd.read_csv('data/00-raw/GLOBEMDataset/INS-W_3/FeatureData/sleep.csv')
df_sleep_21 = pd.read_csv('data/00-raw/GLOBEMDataset/INS-W_4/FeatureData/sleep.csv')

# %% [markdown]
# We know each year is formatted the same. Let's take a look at the shape of the dataframe of 2019 as well as the first few rows.

# %%
print(df_sleep_19.shape)
df_sleep_19.head()
# Out:
# (21146, 921)
#    Unnamed: 0        pid        date  \
# 0           0  INS-W_300  2019-03-21
# 1           1  INS-W_300  2019-03-22
# 2           2  INS-W_300  2019-03-23
# 3           3  INS-W_300  2019-03-24
# 4           4  INS-W_300  2019-03-25
#
#    f_slp:fitbit_sleep_summary_rapids_sumdurationafterwakeupmain:14dhist  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:14dhist  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# ...

# %% [markdown]
# That's a lot of columns! We are focusing on 'main' nightly sleep duration and don't need most of these columns. We will also be removing the duplicate index column like before. After that, we will rename our desired sleep column and drop any rows with missing values.

# %%
# Create a list of columns we want to keep in our dataframe.
sleep_keep_columns = ['pid', 'date', 'f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:14dhist']

# Create dfs using only the desired columns.
df_19_sleep_1 = df_sleep_19[sleep_keep_columns]
df_20_sleep_1 = df_sleep_20[sleep_keep_columns]
df_21_sleep_1 = df_sleep_21[sleep_keep_columns]

# Rename the sleep duration column.
df_19_sleep_1.rename(columns={'f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:14dhist': 'sumdurationsleepmain:14dhist'}, inplace=True)
df_20_sleep_1.rename(columns={'f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:14dhist': 'sumdurationsleepmain:14dhist'}, inplace=True)
df_21_sleep_1.rename(columns={'f_slp:fitbit_sleep_summary_rapids_sumdurationasleepmain:14dhist': 'sumdurationsleepmain:14dhist'}, inplace=True)

# Drop rows with missing values.
df_19_sleep_cleaned = df_19_sleep_1.dropna(axis=0, how='any', inplace=False)
df_20_sleep_cleaned = df_20_sleep_1.dropna(axis=0, how='any', inplace=False)
df_21_sleep_cleaned = df_21_sleep_1.dropna(axis=0, how='any', inplace=False)

# %% [markdown]
# Double check that there are no missing values.

# %%
print(df_19_sleep_cleaned.isnull().any())
print(df_20_sleep_cleaned.isnull().any())
print(df_21_sleep_cleaned.isnull().any())
# Out:
# pid                             False
# date                            False
# sumdurationsleepmain:14dhist    False
# dtype: bool
# pid                             False
# date                            False
# sumdurationsleepmain:14dhist    False
# dtype: bool
# pid                             False
# date                            False
# sumdurationsleepmain:14dhist    False
# dtype: bool

# %% [markdown]
# ### Seattle Historical Weather Dataset
#
# This dataset provides a hourly historical record of temperature in Seattle, Washington.This dataset consists of 3 subsets, 2019 historical weather data includes temperature data from March 21 to June 25 in 2019, historical weather data in 2020 included temperature data from March 16 to June 16 in this year and historical weather data in 2021 includes temperature data from March 29 to July 9 in this year. The only variable included is temperature measured in degrees Fahrenheit (°F). Because temperature is the only variable included, this dataset focuses exclusively on thermal patterns without accompanying information about precipitation, wind, humidity, or atmospheric pressure. Air temperature in °F reflects how hot or cold the air is at the time of measurement.
#
# In Seattle’s marine climate, typical spring temperatures range from about 45–55°F, while summer temperatures generally range from 60–85°F. Values above 90°F are relatively uncommon and may indicate a heatwave, while temperatures below 32°F indicate freezing conditions. Extremely high temperatures (e.g., above 100°F) are rare but potentially dangerous, increasing the risk of heat exhaustion and heat stroke. In addition,temperatures below 20°F would be considered unusually cold for Seattle and could pose risks and safety concerns.
#
# A primary concern of this dataset is the presence of extreme climatic outliers due to significant climate change. For instance, the June 2021 Pacific Northwest Heat Dome. During this event, the temperature is rising sharply, reaching above 90°F, which creates a significant statistical skew. Moreover, since the dataset does not include variables such as precipitation or cloud cover, it does not provide a complete picture of overall weather conditions. For example, a 45°F day in Seattle can feel very different depending on whether it is bright and sunny or marked by the city’s characteristic gray skies and light mist. Additionally, because most historical weather APIs source their data from Seattle-Tacoma International Airport, the recorded temperatures may differ by several degrees from those observed in other part of the city.

# %% [markdown]
# #### 2019 Historical Weather Data (open-meteo-47.63N122.32W59m-2019.csv)

# %%
w19 = pd.read_csv('data/00-raw/weather-2019.csv') 
print("\nRaw dataset:\n",w19.head())
#change column name and clear first two row
w19_tidy = w19.rename(columns={'latitude': 'date', 'longitude': 'avg_temperature_F'}) #change column name
w19_tidy = w19_tidy.iloc[2:] 
print("\nTidied dataset:\n",w19_tidy.head())

w19_tidy.to_csv('data/01-interim/weather-2019_tidied.csv',index=False)
print(f"\nTidying complete. Processed file saved to: 'data/01-interim/weather-2019_tidied.csv'")

#THE SIZE OF THE DATASET
print(f"\nDataset Shape: {w19_tidy.shape}")

#MISSING DATA
missing_counts = w19_tidy.isnull().sum()
print("\nMissing values per column:\n", missing_counts)

#OUTLIERS AND SUSPICIOUS ENTRIES
w19_tidy['avg_temperature_F'] = pd.to_numeric(w19_tidy['avg_temperature_F'], errors='coerce')
q1 = w19_tidy['avg_temperature_F'].quantile(0.25)
q3 = w19_tidy['avg_temperature_F'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = w19_tidy[(w19_tidy['avg_temperature_F'] < lower_bound) | (w19_tidy['avg_temperature_F'] > upper_bound)]
w19_tidy['is_outlier'] = (w19_tidy['avg_temperature_F'] < lower_bound) | (w19_tidy['avg_temperature_F'] > upper_bound)

print(f"\nNumber of statistical outliers found: {len(outliers)}")
print("\nOutliers flagged\n",w19_tidy.head())

#DATA CLEANING
#w19_clean = w19_tidy[w19_tidy['is_outlier'] == False]
w19_clean = w19_tidy[['date','avg_temperature_F']].copy()

#change hourly data to daily data
w19_clean['date'] = pd.to_datetime(w19_clean['date'])
w19_clean = w19_clean.set_index('date')
w19_clean = w19_clean.resample('D').mean().reset_index()
w19_clean['avg_temperature_F'] = w19_clean['avg_temperature_F'].round(1)
w19_clean = w19_clean.infer_objects(copy=False)

print("\nCleaned dataset:\n",w19_clean.head())
w19_clean.to_csv('data/02-processed/weather-2019_cleaned.csv',index=False)
print(f"\nWrangling complete. Processed file saved to: 'data/02-processed/weather-2019_cleaned.csv'")
# Out:
# Raw dataset:
#             latitude            longitude  elevation  utc_offset_seconds  \
# 0         47.627415           -122.32291       59.0            -28800.0
# 1              time  temperature_2m (°F)        NaN                 NaN
# 2  2019-03-21T00:00                 51.3        NaN                 NaN
# 3  2019-03-21T01:00                 50.6        NaN                 NaN
# 4  2019-03-21T02:00                 49.7        NaN                 NaN
#
#               timezone timezone_abbreviation
# 0  America/Los_Angeles                 GMT-8
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
# Tidied dataset:
#                 date avg_temperature_F  elevation  utc_offset_seconds timezone  \
# 2  2019-03-21T00:00              51.3        NaN                 NaN      NaN
# ...

# %% [markdown]
# #### 2020 Historical Weather Data (open-meteo-47.63N122.32W59m-2020.csv)

# %%
w20 = pd.read_csv('data/00-raw/weather-2020.csv') 
print("\nRaw dataset:\n",w20.head())
#TIDY DATA
w20_tidy = w20.rename(columns={'latitude': 'date', 'longitude': 'avg_temperature_F'}) #change column name
w20_tidy = w20_tidy.iloc[2:] 
print("\nTidied dataset:\n",w20_tidy.head())

w20_tidy.to_csv('data/01-interim/weather-2020_tidied.csv',index=False)
print(f"\nTidying complete. Processed file saved to: 'data/01-interim/weather-2020_tidied.csv'")

#THE SIZE OF THE DATASET
print(f"\nDataset Shape: {w20_tidy.shape}")

#MISSING DATA
missing_counts = w20_tidy.isnull().sum()
print("\nMissing values per column:\n", missing_counts)

#OUTLIERS AND SUSPICIOUS ENTRIES
w20_tidy['avg_temperature_F'] = pd.to_numeric(w20_tidy['avg_temperature_F'], errors='coerce')
q1 = w20_tidy['avg_temperature_F'].quantile(0.25)
q3 = w20_tidy['avg_temperature_F'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = w20_tidy[(w20_tidy['avg_temperature_F'] < lower_bound) | (w20_tidy['avg_temperature_F'] > upper_bound)]
w20_tidy['is_outlier'] = (w20_tidy['avg_temperature_F'] < lower_bound) | (w20_tidy['avg_temperature_F'] > upper_bound)

print(f"\nNumber of statistical outliers found: {len(outliers)}")
print("\nOutliers flagged\n",w20_tidy.head())

#DATA CLEANING
#w20_clean = w20_tidy[w20_tidy['is_outlier'] == False]
w20_clean = w20_tidy[['date','avg_temperature_F']].copy()
#change hourly data to daily data
w20_clean['date'] = pd.to_datetime(w20_clean['date'])
w20_clean = w20_clean.set_index('date')
w20_clean = w20_clean.resample('D').mean().reset_index()
w20_clean['avg_temperature_F'] = w20_clean['avg_temperature_F'].round(1)
w20_clean = w20_clean.infer_objects(copy=False)

print("\nCleaned dataset:\n",w20_clean.head())
w20_clean.to_csv('data/02-processed/weather-2020_cleaned.csv',index=False)
print(f"\nWrangling complete. Processed file saved to: 'data/02-processed/weather-2020_cleaned.csv'")
# Out:
# Raw dataset:
#             latitude            longitude  elevation  utc_offset_seconds  \
# 0         47.627415           -122.32291       59.0            -28800.0
# 1              time  temperature_2m (°F)        NaN                 NaN
# 2  2020-03-16T00:00                 39.6        NaN                 NaN
# 3  2020-03-16T01:00                 39.1        NaN                 NaN
# 4  2020-03-16T02:00                 39.2        NaN                 NaN
#
#               timezone timezone_abbreviation
# 0  America/Los_Angeles                 GMT-8
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
# Tidied dataset:
#                 date avg_temperature_F  elevation  utc_offset_seconds timezone  \
# 2  2020-03-16T00:00              39.6        NaN                 NaN      NaN
# ...

# %% [markdown]
# #### 2021 Historical Weather Data (open-meteo-47.63N122.32W59m-2021.csv)

# %%
w21 = pd.read_csv('data/00-raw/weather-2021.csv') 
print("\nRaw dataset:\n",w21.head())
#change column name and clear first two row
w21_tidy = w21.rename(columns={'latitude': 'date', 'longitude': 'avg_temperature_F'}) #change column name
w21_tidy = w21_tidy.iloc[2:] 
print("\nTidied dataset:\n",w21_tidy.head())

w21_tidy.to_csv('data/01-interim/weather-2021_tidied.csv',index=False)
print(f"\nTidying complete. Processed file saved to: 'data/01-interim/weather-2021_tidied.csv'")

#THE SIZE OF THE DATASET
print(f"\nDataset Shape: {w21_tidy.shape}")

#MISSING DATA
missing_counts = w21_tidy.isnull().sum()
print("\nMissing values per column:\n", missing_counts)

#OUTLIERS AND SUSPICIOUS ENTRIES
w21_tidy['avg_temperature_F'] = pd.to_numeric(w21_tidy['avg_temperature_F'], errors='coerce')
q1 = w21_tidy['avg_temperature_F'].quantile(0.25)
q3 = w21_tidy['avg_temperature_F'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = w21_tidy[(w21_tidy['avg_temperature_F'] < lower_bound) | (w21_tidy['avg_temperature_F'] > upper_bound)]
w21_tidy['is_outlier'] = (w21_tidy['avg_temperature_F'] < lower_bound) | (w21_tidy['avg_temperature_F'] > upper_bound)

print(f"\nNumber of statistical outliers found: {len(outliers)}")
print("\nOutliers flagged\n",w21_tidy.head())

#DATA CLEANING
#w21_clean = w21_tidy[w21_tidy['is_outlier'] == False]
w21_clean = w21_tidy[['date','avg_temperature_F']].copy()

#change hourly data to daily data
w21_clean['date'] = pd.to_datetime(w21_clean['date'])
w21_clean = w21_clean.set_index('date')
w21_clean = w21_clean.resample('D').mean().reset_index()
w21_clean['avg_temperature_F'] = w21_clean['avg_temperature_F'].round(1)
w21_clean = w21_clean.infer_objects(copy=False)

print("\nCleaned dataset:\n",w21_clean.head())
w21_clean.to_csv('data/02-processed/weather-2021_cleaned.csv',index=False)
print(f"\nWrangling complete. Processed file saved to: 'data/02-processed/weather-2021_cleaned.csv'")
# Out:
# Raw dataset:
#             latitude            longitude  elevation  utc_offset_seconds  \
# 0         47.627415           -122.32291       59.0            -28800.0
# 1              time  temperature_2m (°F)        NaN                 NaN
# 2  2021-03-29T00:00                 38.5        NaN                 NaN
# 3  2021-03-29T01:00                 37.7        NaN                 NaN
# 4  2021-03-29T02:00                 37.1        NaN                 NaN
#
#               timezone timezone_abbreviation
# 0  America/Los_Angeles                 GMT-8
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
# Tidied dataset:
#                 date avg_temperature_F  elevation  utc_offset_seconds timezone  \
# 2  2021-03-29T00:00              38.5        NaN                 NaN      NaN
# ...

# %% [markdown]
# #### Visualization of Datasets Cleanliness

# %%
datasets = {
    "2019 Weather Data": w19_clean,
    "2020 Weather Data": w20_clean,
    "2021 Weather Data": w21_clean
}
missing_summary = {}

for name, df in datasets.items():
    missing_summary[name] = df.isnull().mean() * 100

missing_df = pd.DataFrame(missing_summary)
print(missing_df)

import matplotlib.pyplot as plt

missing_df.T.plot(kind='bar', figsize=(5,3))

plt.ylabel("Percent Missing")
plt.title("Missing Data Percentage Comparison Across Datasets")
plt.xticks(rotation=45)
plt.legend(title="Columns")
plt.show()
# Out:
#                    2019 Weather Data  2020 Weather Data  2021 Weather Data
# date                             0.0                0.0                0.0
# avg_temperature_F                0.0                0.0                0.0

# %% [markdown]
# ### Seattle Historical Weather Dataset
# This dataset provides a hourly historical record of temperature in Seattle, Washington.This dataset consists of 3 subsets, 2019 historical weather data includes temperature data from March 21 to June 25 in 2019, historical weather data in 2020 included temperature data from March 16 to June 16 in this year and historical weather data in 2021 includes temperature data from March 29 to July 9 in this year. The only variable included is temperature measured in degrees Fahrenheit (°F). Because temperature is the only variable included, this dataset focuses exclusively on thermal patterns without accompanying information about precipitation, wind, humidity, or atmospheric pressure. Air temperature in °F reflects how hot or cold the air is at the time of measurement.
#
# In Seattle’s marine climate, typical spring temperatures range from about 45–55°F, while summer temperatures generally range from 60–85°F. Values above 90°F are relatively uncommon and may indicate a heatwave, while temperatures below 32°F indicate freezing conditions. Extremely high temperatures (e.g., above 100°F) are rare but potentially dangerous, increasing the risk of heat exhaustion and heat stroke. In addition,temperatures below 20°F would be considered unusually cold for Seattle and could pose risks and safety concerns.
#
# A primary concern of this dataset is the presence of extreme climatic outliers due to significant climate change. For instance, the June 2021 Pacific Northwest Heat Dome. During this event, the temperature is rising sharply, reaching above 90°F, which creates a significant statistical skew. Moreover, since the dataset does not include variables such as precipitation or cloud cover, it does not provide a complete picture of overall weather conditions. For example, a 45°F day in Seattle can feel very different depending on whether it is bright and sunny or marked by the city’s characteristic gray skies and light mist. Additionally, because most historical weather APIs source their data from Seattle-Tacoma International Airport, the recorded temperatures may differ by several degrees from those observed in other part of the city.

# %% [markdown]
# #### 2019 Historical Weather Data (open-meteo-47.63N122.32W59m-2019.csv)

# %%
w19 = pd.read_csv('data/00-raw/weather-2019.csv') 
print("\nRaw dataset:\n",w19.head())
#change column name and clear first two row
w19_tidy = w19.rename(columns={'latitude': 'date', 'longitude': 'avg_temperature_F'}) #change column name
w19_tidy = w19_tidy.iloc[2:] 
print("\nTidied dataset:\n",w19_tidy.head())

w19_tidy.to_csv('data/01-interim/weather-2019_tidied.csv',index=False)
print(f"\nTidying complete. Processed file saved to: 'data/01-interim/weather-2019_tidied.csv'")

#THE SIZE OF THE DATASET
print(f"\nDataset Shape: {w19_tidy.shape}")

#MISSING DATA
missing_counts = w19_tidy.isnull().sum()
print("\nMissing values per column:\n", missing_counts)

#OUTLIERS AND SUSPICIOUS ENTRIES
w19_tidy['avg_temperature_F'] = pd.to_numeric(w19_tidy['avg_temperature_F'], errors='coerce')
q1 = w19_tidy['avg_temperature_F'].quantile(0.25)
q3 = w19_tidy['avg_temperature_F'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = w19_tidy[(w19_tidy['avg_temperature_F'] < lower_bound) | (w19_tidy['avg_temperature_F'] > upper_bound)]
w19_tidy['is_outlier'] = (w19_tidy['avg_temperature_F'] < lower_bound) | (w19_tidy['avg_temperature_F'] > upper_bound)

print(f"\nNumber of statistical outliers found: {len(outliers)}")
print("\nOutliers flagged\n",w19_tidy.head())

#DATA CLEANING
#w19_clean = w19_tidy[w19_tidy['is_outlier'] == False]
w19_clean = w19_tidy[['date','avg_temperature_F']].copy()

#change hourly data to daily data
w19_clean['date'] = pd.to_datetime(w19_clean['date'])
w19_clean = w19_clean.set_index('date')
w19_clean = w19_clean.resample('D').mean().reset_index()
w19_clean['avg_temperature_F'] = w19_clean['avg_temperature_F'].round(1)
w19_clean = w19_clean.infer_objects(copy=False)

print("\nCleaned dataset:\n",w19_clean.head())
w19_clean.to_csv('data/02-processed/weather-2019_cleaned.csv',index=False)
print(f"\nWrangling complete. Processed file saved to: 'data/02-processed/weather-2019_cleaned.csv'")
# Out:
# Raw dataset:
#             latitude            longitude  elevation  utc_offset_seconds  \
# 0         47.627415           -122.32291       59.0            -28800.0
# 1              time  temperature_2m (°F)        NaN                 NaN
# 2  2019-03-21T00:00                 51.3        NaN                 NaN
# 3  2019-03-21T01:00                 50.6        NaN                 NaN
# 4  2019-03-21T02:00                 49.7        NaN                 NaN
#
#               timezone timezone_abbreviation
# 0  America/Los_Angeles                 GMT-8
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
# Tidied dataset:
#                 date avg_temperature_F  elevation  utc_offset_seconds timezone  \
# 2  2019-03-21T00:00              51.3        NaN                 NaN      NaN
# ...

# %% [markdown]
# #### 2020 Historical Weather Data (open-meteo-47.63N122.32W59m-2020.csv)

# %%
w20 = pd.read_csv('data/00-raw/weather-2020.csv') 
print("\nRaw dataset:\n",w20.head())
#TIDY DATA
w20_tidy = w20.rename(columns={'latitude': 'date', 'longitude': 'avg_temperature_F'}) #change column name
w20_tidy = w20_tidy.iloc[2:] 
print("\nTidied dataset:\n",w20_tidy.head())

w20_tidy.to_csv('data/01-interim/weather-2020_tidied.csv',index=False)
print(f"\nTidying complete. Processed file saved to: 'data/01-interim/weather-2020_tidied.csv'")

#THE SIZE OF THE DATASET
print(f"\nDataset Shape: {w20_tidy.shape}")

#MISSING DATA
missing_counts = w20_tidy.isnull().sum()
print("\nMissing values per column:\n", missing_counts)

#OUTLIERS AND SUSPICIOUS ENTRIES
w20_tidy['avg_temperature_F'] = pd.to_numeric(w20_tidy['avg_temperature_F'], errors='coerce')
q1 = w20_tidy['avg_temperature_F'].quantile(0.25)
q3 = w20_tidy['avg_temperature_F'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = w20_tidy[(w20_tidy['avg_temperature_F'] < lower_bound) | (w20_tidy['avg_temperature_F'] > upper_bound)]
w20_tidy['is_outlier'] = (w20_tidy['avg_temperature_F'] < lower_bound) | (w20_tidy['avg_temperature_F'] > upper_bound)

print(f"\nNumber of statistical outliers found: {len(outliers)}")
print("\nOutliers flagged\n",w20_tidy.head())

#DATA CLEANING
#w20_clean = w20_tidy[w20_tidy['is_outlier'] == False]
w20_clean = w20_tidy[['date','avg_temperature_F']].copy()
#change hourly data to daily data
w20_clean['date'] = pd.to_datetime(w20_clean['date'])
w20_clean = w20_clean.set_index('date')
w20_clean = w20_clean.resample('D').mean().reset_index()
w20_clean['avg_temperature_F'] = w20_clean['avg_temperature_F'].round(1)
w20_clean = w20_clean.infer_objects(copy=False)

print("\nCleaned dataset:\n",w20_clean.head())
w20_clean.to_csv('data/02-processed/weather-2020_cleaned.csv',index=False)
print(f"\nWrangling complete. Processed file saved to: 'data/02-processed/weather-2020_cleaned.csv'")
# Out:
# Raw dataset:
#             latitude            longitude  elevation  utc_offset_seconds  \
# 0         47.627415           -122.32291       59.0            -28800.0
# 1              time  temperature_2m (°F)        NaN                 NaN
# 2  2020-03-16T00:00                 39.6        NaN                 NaN
# 3  2020-03-16T01:00                 39.1        NaN                 NaN
# 4  2020-03-16T02:00                 39.2        NaN                 NaN
#
#               timezone timezone_abbreviation
# 0  America/Los_Angeles                 GMT-8
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
# Tidied dataset:
#                 date avg_temperature_F  elevation  utc_offset_seconds timezone  \
# 2  2020-03-16T00:00              39.6        NaN                 NaN      NaN
# ...

# %% [markdown]
# #### 2021 Historical Weather Data (open-meteo-47.63N122.32W59m-2021.csv)

# %%
w21 = pd.read_csv('data/00-raw/weather-2021.csv') 
print("\nRaw dataset:\n",w21.head())
#change column name and clear first two row
w21_tidy = w21.rename(columns={'latitude': 'date', 'longitude': 'avg_temperature_F'}) #change column name
w21_tidy = w21_tidy.iloc[2:] 
print("\nTidied dataset:\n",w21_tidy.head())

w21_tidy.to_csv('data/01-interim/weather-2021_tidied.csv',index=False)
print(f"\nTidying complete. Processed file saved to: 'data/01-interim/weather-2021_tidied.csv'")

#THE SIZE OF THE DATASET
print(f"\nDataset Shape: {w21_tidy.shape}")

#MISSING DATA
missing_counts = w21_tidy.isnull().sum()
print("\nMissing values per column:\n", missing_counts)

#OUTLIERS AND SUSPICIOUS ENTRIES
w21_tidy['avg_temperature_F'] = pd.to_numeric(w21_tidy['avg_temperature_F'], errors='coerce')
q1 = w21_tidy['avg_temperature_F'].quantile(0.25)
q3 = w21_tidy['avg_temperature_F'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = w21_tidy[(w21_tidy['avg_temperature_F'] < lower_bound) | (w21_tidy['avg_temperature_F'] > upper_bound)]
w21_tidy['is_outlier'] = (w21_tidy['avg_temperature_F'] < lower_bound) | (w21_tidy['avg_temperature_F'] > upper_bound)

print(f"\nNumber of statistical outliers found: {len(outliers)}")
print("\nOutliers flagged\n",w21_tidy.head())

#DATA CLEANING
#w21_clean = w21_tidy[w21_tidy['is_outlier'] == False]
w21_clean = w21_tidy[['date','avg_temperature_F']].copy()

#change hourly data to daily data
w21_clean['date'] = pd.to_datetime(w21_clean['date'])
w21_clean = w21_clean.set_index('date')
w21_clean = w21_clean.resample('D').mean().reset_index()
w21_clean['avg_temperature_F'] = w21_clean['avg_temperature_F'].round(1)
w21_clean = w21_clean.infer_objects(copy=False)

print("\nCleaned dataset:\n",w21_clean.head())
w21_clean.to_csv('data/02-processed/weather-2021_cleaned.csv',index=False)
print(f"\nWrangling complete. Processed file saved to: 'data/02-processed/weather-2021_cleaned.csv'")
# Out:
# Raw dataset:
#             latitude            longitude  elevation  utc_offset_seconds  \
# 0         47.627415           -122.32291       59.0            -28800.0
# 1              time  temperature_2m (°F)        NaN                 NaN
# 2  2021-03-29T00:00                 38.5        NaN                 NaN
# 3  2021-03-29T01:00                 37.7        NaN                 NaN
# 4  2021-03-29T02:00                 37.1        NaN                 NaN
#
#               timezone timezone_abbreviation
# 0  America/Los_Angeles                 GMT-8
# 1                  NaN                   NaN
# 2                  NaN                   NaN
# 3                  NaN                   NaN
# 4                  NaN                   NaN
#
# Tidied dataset:
#                 date avg_temperature_F  elevation  utc_offset_seconds timezone  \
# 2  2021-03-29T00:00              38.5        NaN                 NaN      NaN
# ...

# %% [markdown]
# #### Visualization of Datasets Cleanliness

# %%
datasets = {
    "2019 Weather Data": w19_clean,
    "2020 Weather Data": w20_clean,
    "2021 Weather Data": w21_clean
}
missing_summary = {}

for name, df in datasets.items():
    missing_summary[name] = df.isnull().mean() * 100

missing_df = pd.DataFrame(missing_summary)
print(missing_df)

import matplotlib.pyplot as plt

missing_df.T.plot(kind='bar', figsize=(5,3))

plt.ylabel("Percent Missing")
plt.title("Missing Data Percentage Comparison Across Datasets")
plt.xticks(rotation=45)
plt.legend(title="Columns")
plt.show()
# Out:
#                    2019 Weather Data  2020 Weather Data  2021 Weather Data
# date                             0.0                0.0                0.0
# avg_temperature_F                0.0                0.0                0.0

# %% [markdown]
# Since the percentage of missing data for both date and temperature is 0.0% across all years, the dataset is considered complete and clean in missing data perspective.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - \[X\] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Subjects were recruited and compensated for their participation in studies. Participation was voluntary and consent forms were signed.
#
#  - \[X\] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Subjects were all university students which classifies them as WEIRD subjects. Research question formulated to be specific to only university students.
#
#  - \[X\] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > IRB rules were followed to anonymize participant data. Only feature-level data was released to protect privacy.
#
#  - \[X\] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > Our group does not have access to demographics information as it is protected and needs to be specially requested therefore we are unable to directly evaluate whether our downstream analyses produce disparate outcomes across protected groups. We acknowledge this constraint and avoid making claims about demographic disparities.
#
# ### B. Data Storage
#  - \[X\] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > Some of the data used is publicly available government information. Restricted data will be used strictly for analytical and modeling purposes. Models will be published but data will not be released.
#
#  - \[X\] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - \[X\] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > Data will be deleted off of local drives after this project is completed.
#
# ### C. Analysis
#  - \[X\] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > While not engaging directly with relevant stakeholders, we sought to mitigate blind spots by reviewing the literature on the use of PHQ-4 which we will use as our measure for anxiety and depression scores. By reviewing similar studies to ours we have found that the PHQ-4 is a valid self reported measure of anxiety and depression. We will not be interpreting PHQ-4 scores for clinical diagnosis.
#
#  - \[X\] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Potential sources of bias could come from self reported longitudinal data on anxiety and depression which may be a source of reporting bias stigma, or survey fatigue. Because of this we will not be using this data as a diagnostic tool for participants but rather interpret it as a screening tool. There is also potential for attrition bias due to the duration of the study that we have taken into account. Because of the lack of demographic information and contextual variables, we will refrain from making casual interpretations.
#
#  - \[X\] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - \[X\] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > Personal identifiers are not provided in the original data set.
#
#  - \[X\] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > All of our steps are well documented with ample commentary for future reference.
#
# ### D. Modeling
#
# As we are not planning on creating a model, these questions do not significantly apply to our project.
#  - \[X\] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - \[X\] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - \[X\] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - \[X\] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - \[X\] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#
# As we are not planning on creating a model, these questions do not significantly apply to our project.
#  - \[X\] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - \[X\] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - \[X\] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - \[X\] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * Use iMessage group chat for communication
#     * Respond within 24 hours
#     * Be direct and polite
# * Meet at least 1-2 times per week with at least 1 in person meeting
# * Unanimous voting regarding decisions
#     * If a teammate is nonresponsive, the decision is already set even if they disagree afterwards
# * Regarding large scale project work - everyone does a little bit
#     * For more technical individual work, specific tasks will be assigned
# * Google sheets for tasks
#     * Send a quick update to group chat if you add, complete, or need help with a task
# * Let the group know as early as possible about busy schedule and potential inability to complete tasks
#     * The rest of the people can split the unfinished task – this can be discussed based on the specific task
#     * Maximum times you can ask the group to complete your assigned task: either 1 large task or 2 small tasks

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Bolded and italicized dates indicate in person meetings. People will be assigned to specific tasks as more progress is made and what exactly needs to be done becomes clearer.
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/3  |  5:30 PM | N/A  | Discuss project proposal; Come up with research question; Set team expectations |
# | 2/4  |  6:30 PM |  Do individual research to contribute to background + prior work; Look for datasets; Formulate own hypotheses to discuss with group | Finalize and submit project proposal |
# | 2/10  |  5:30 PM  | Look into more datasets, be prepared to discuss with group  | Pick 2-3 datasets to finalize for project; Start dataset descriptions + ethics   |
# | 2/13  | 5:30 PM  | Work on dataset descriptions and ethics | Discuss wrangling and possible analytical approaches   |
# | 2/16  | 11:00 AM  | Work on dataset descriptions and ethics | Discuss wrangling and possible analytical approaches   |
# | 2/20  | 5:30 PM  | Import + wrangle data; Prepare to discuss successes and problems with group | Discuss progress regarding wrangling; Make necessary changes |
# | ***3/3***  | 5:30 PM  | Continue working on data (EDA)| Finalize and submit EDA checkpoint |
# | 3/10  | 5:30 PM  | Brainstorm for final video and how to finalize project | Discuss final video + project; Create a plan for filming and submission |
# | ***3/12***  | 5:30 PM  | Have individual part of final video done; Prepare for final video | Film final video |
# | 3/14  | 12:00 PM  | Finalize project; edit final video | Complete Team Evaluation Survey; Finalize and submit everything! |
